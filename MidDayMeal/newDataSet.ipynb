# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('feature.csv',header=None)
df[0:3][0:7]
# Out:
#             0            1            2            3            4   \
# 0    Enr Govt1    Enr Govt2    Enr Govt3    Enr Govt4    Enr Govt5
# 1     Enr Pvt1     Enr Pvt2     Enr Pvt3     Enr Pvt4     Enr Pvt5
# 2  Enr R Govt1  Enr R Govt2  Enr R Govt3  Enr R Govt4  Enr R Govt5
#
#             5            6            7    8    9  ...    11   12   13   14  \
# 0    Enr Govt6    Enr Govt7    Enr Govt9  NaN  NaN ...   NaN  NaN  NaN  NaN
# 1     Enr Pvt6     Enr Pvt7     Enr Pvt9  NaN  NaN ...   NaN  NaN  NaN  NaN
# 2  Enr R Govt6  Enr R Govt7  Enr R Govt9  NaN  NaN ...   NaN  NaN  NaN  NaN
#
#     15   16   17   18   19   20
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN
#
# [3 rows x 21 columns]

# %%
newDf = pd.read_csv('Enr_Karnataka2013-14.csv',header = None)
commonDf = pd.concat([newDf[[0,1]]], axis=1)
start = 2
end = start + 7
temp = pd.concat([newDf[a]],axis=1)
temp
#fileDf = pd.concat(commonDf,temp,axis =1)
#fileDf
# Out:
#             2          3          4          5          6          7  \
# 0   Enr Govt1  Enr Govt2  Enr Govt3  Enr Govt4  Enr Govt5  Enr Govt6
# 1       22704     163024          0        811        727       8472
# 2       15355      41088          0        198        778          0
# 3       10208      54698       8263          0        226       3431
# 4       18244      82133       4665          0          0        622
# 5       22500     156725       2433        600          0       2017
# 6       28543     188465          0        302        919       5043
# 7       29007     189994        341        656          0       4794
# 8       22301     129063          0        599        248        936
# 9       34565     221854        672        505        328          0
# 10      11482      54857          0        596          0        224
# 11      22977      53549          0        699        322       1195
# 12      15318      52146          0          0          0        148
# ...

# %%
sequence = [2,3,4,5,6,7,8,9]
temp = pd.concat([newDf[sequence]],axis=1)
temp.to_csv("result.csv")
sequence = []
for i in range(10,162):
    if(len(sequence) == 8):
        arg = sequence
        temp = pd.concat([newDf[arg]],axis=1)
        temp.to_csv("result" + str(i) + ".csv")
        sequence = []
    else:    
        sequence.append(i)
    
    
    #fileDf = pd.concat((commonDf,temp),axis =1)
    #fileDf.to_csv("result" + str(i) + ".csv")
    
#sequence

# %%
seq = []
start = 1
end = 8
arg1 = []
for i in range(0,16):
    if(i+1 % 8 == 0):
        arg1 = seq[(start+1):(end+1)]
    #seq.append(i)

print(arg1)
# Out:
# []
